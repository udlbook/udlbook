# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/ly/jkydg4dj2vs93b_ds7yp5t7r0000gn/T/pip-req-build-keljy0uw
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/ly/jkydg4dj2vs93b_ds7yp5t7r0000gn/T/pip-req-build-keljy0uw
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: matplotlib in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/tomg/Source/courses/dl4ds/udlbook/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14625 sha256=446bf0929db6bffb2d1bd8741e5b976916266acb8b25b7572eb463f503476103
#   Stored in directory: /private/var/folders/ly/jkydg4dj2vs93b_ds7yp5t7r0000gn/T/pip-ephem-wheel-cache-3_3egf0v/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
#   Attempting uninstall: mnist1d
#     Found existing installation: mnist1d 0.0.2.post1
#     Uninstalling mnist1d-0.0.2.post1:
#       Successfully uninstalled mnist1d-0.0.2.post1
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.188651, train error 82.47,  test loss 2.141529, test error 82.68
# Epoch   100, train loss 1.929997, train error 72.82,  test loss 1.762301, test error 70.03
# Epoch   200, train loss 1.919343, train error 71.93,  test loss 1.743890, test error 68.82
# Epoch   300, train loss 1.909866, train error 71.65,  test loss 1.739821, test error 69.28
# Epoch   400, train loss 1.911616, train error 70.88,  test loss 1.756073, test error 69.05
# Epoch   500, train loss 1.909097, train error 71.25,  test loss 1.745124, test error 69.05
# Epoch   600, train loss 1.907653, train error 71.95,  test loss 1.744872, test error 68.62
# Epoch   700, train loss 1.912194, train error 71.32,  test loss 1.737123, test error 69.88
# Epoch   800, train loss 1.904978, train error 71.35,  test loss 1.733905, test error 69.50
# Epoch   900, train loss 1.906015, train error 72.15,  test loss 1.732038, test error 68.70
# Training model with   4 hidden variables
# Epoch     0, train loss 2.262984, train error 84.38,  test loss 2.258343, test error 84.60
# Epoch   100, train loss 1.718990, train error 63.47,  test loss 1.513328, test error 58.42
# Epoch   200, train loss 1.704074, train error 61.88,  test loss 1.506221, test error 58.45
# Epoch   300, train loss 1.698645, train error 61.62,  test loss 1.502013, test error 58.17
# Epoch   400, train loss 1.704418, train error 62.58,  test loss 1.506124, test error 58.53
# Epoch   500, train loss 1.700263, train error 61.92,  test loss 1.509595, test error 58.62
# Epoch   600, train loss 1.700059, train error 61.62,  test loss 1.506440, test error 58.35
# Epoch   700, train loss 1.701732, train error 61.60,  test loss 1.504804, test error 58.12
# Epoch   800, train loss 1.703249, train error 61.67,  test loss 1.512480, test error 58.75
# Epoch   900, train loss 1.703175, train error 61.97,  test loss 1.497916, test error 57.55
# Training model with   6 hidden variables
# Epoch     0, train loss 2.288470, train error 87.28,  test loss 2.275385, test error 86.78
# Epoch   100, train loss 1.684353, train error 59.75,  test loss 1.492137, test error 58.50
# Epoch   200, train loss 1.634369, train error 58.30,  test loss 1.449672, test error 56.15
# Epoch   300, train loss 1.607675, train error 57.53,  test loss 1.445940, test error 54.62
# Epoch   400, train loss 1.595218, train error 57.22,  test loss 1.442103, test error 54.90
# Epoch   500, train loss 1.587062, train error 57.08,  test loss 1.441756, test error 55.17
# Epoch   600, train loss 1.586095, train error 56.40,  test loss 1.440599, test error 55.33
# Epoch   700, train loss 1.587714, train error 56.62,  test loss 1.461088, test error 55.83
# Epoch   800, train loss 1.579335, train error 55.75,  test loss 1.445110, test error 55.22
# Epoch   900, train loss 1.576545, train error 56.00,  test loss 1.445779, test error 54.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.170950, train error 80.07,  test loss 2.130657, test error 78.72
# Epoch   100, train loss 1.628760, train error 57.60,  test loss 1.444226, test error 54.70
# Epoch   200, train loss 1.574901, train error 56.70,  test loss 1.428759, test error 54.33
# Epoch   300, train loss 1.531725, train error 53.83,  test loss 1.400798, test error 53.25
# Epoch   400, train loss 1.520283, train error 53.70,  test loss 1.393861, test error 53.35
# Epoch   500, train loss 1.502731, train error 52.80,  test loss 1.380798, test error 52.92
# Epoch   600, train loss 1.489157, train error 51.80,  test loss 1.359913, test error 50.90
# Epoch   700, train loss 1.472920, train error 51.08,  test loss 1.328489, test error 49.58
# Epoch   800, train loss 1.465510, train error 51.10,  test loss 1.328635, test error 50.47
# Epoch   900, train loss 1.455504, train error 50.28,  test loss 1.328402, test error 49.97
# Training model with  10 hidden variables
# Epoch     0, train loss 2.271979, train error 87.72,  test loss 2.266071, test error 87.50
# Epoch   100, train loss 1.575878, train error 55.92,  test loss 1.424891, test error 55.30
# Epoch   200, train loss 1.509428, train error 52.45,  test loss 1.392011, test error 51.40
# Epoch   300, train loss 1.455155, train error 49.65,  test loss 1.364775, test error 50.72
# Epoch   400, train loss 1.433424, train error 49.88,  test loss 1.379263, test error 50.35
# Epoch   500, train loss 1.400976, train error 48.33,  test loss 1.362086, test error 50.42
# Epoch   600, train loss 1.391268, train error 48.10,  test loss 1.347871, test error 49.62
# Epoch   700, train loss 1.379258, train error 47.58,  test loss 1.346973, test error 49.78
# Epoch   800, train loss 1.379459, train error 47.28,  test loss 1.350653, test error 50.28
# Epoch   900, train loss 1.377726, train error 47.12,  test loss 1.362670, test error 51.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.141947, train error 79.32,  test loss 2.093221, test error 78.80
# Epoch   100, train loss 1.435383, train error 47.97,  test loss 1.330193, test error 48.97
# Epoch   200, train loss 1.339333, train error 44.78,  test loss 1.294306, test error 47.65
# Epoch   300, train loss 1.300211, train error 44.08,  test loss 1.309353, test error 48.35
# Epoch   400, train loss 1.275913, train error 42.97,  test loss 1.331949, test error 48.75
# Epoch   500, train loss 1.264521, train error 42.55,  test loss 1.359563, test error 49.58
# Epoch   600, train loss 1.257759, train error 42.60,  test loss 1.384930, test error 49.45
# Epoch   700, train loss 1.248266, train error 42.60,  test loss 1.388849, test error 49.72
# Epoch   800, train loss 1.241700, train error 42.83,  test loss 1.406424, test error 49.95
# Epoch   900, train loss 1.236627, train error 42.70,  test loss 1.415561, test error 50.22
# Training model with  18 hidden variables
# Epoch     0, train loss 2.239848, train error 83.95,  test loss 2.225511, test error 83.65
# Epoch   100, train loss 1.371863, train error 46.92,  test loss 1.343231, test error 50.92
# Epoch   200, train loss 1.269949, train error 43.35,  test loss 1.354117, test error 51.62
# Epoch   300, train loss 1.224582, train error 42.62,  test loss 1.419394, test error 51.88
# Epoch   400, train loss 1.206959, train error 42.00,  test loss 1.461347, test error 52.20
# Epoch   500, train loss 1.194437, train error 41.78,  test loss 1.498232, test error 53.20
# Epoch   600, train loss 1.156830, train error 40.35,  test loss 1.485584, test error 51.50
# Epoch   700, train loss 1.159872, train error 40.67,  test loss 1.542413, test error 52.92
# Epoch   800, train loss 1.145388, train error 40.15,  test loss 1.549211, test error 53.25
# Epoch   900, train loss 1.147726, train error 40.85,  test loss 1.591960, test error 53.33
# Training model with  22 hidden variables
# Epoch     0, train loss 2.167782, train error 80.03,  test loss 2.127804, test error 77.75
# Epoch   100, train loss 1.256861, train error 40.83,  test loss 1.288954, test error 47.08
# Epoch   200, train loss 1.158546, train error 39.10,  test loss 1.308055, test error 47.67
# Epoch   300, train loss 1.111374, train error 36.92,  test loss 1.352571, test error 47.72
# Epoch   400, train loss 1.056514, train error 34.53,  test loss 1.388838, test error 48.10
# Epoch   500, train loss 1.026675, train error 33.85,  test loss 1.451022, test error 49.45
# Epoch   600, train loss 1.007181, train error 33.70,  test loss 1.493185, test error 49.55
# Epoch   700, train loss 0.991550, train error 32.78,  test loss 1.539344, test error 50.42
# Epoch   800, train loss 0.990328, train error 33.32,  test loss 1.599206, test error 50.65
# Epoch   900, train loss 0.980530, train error 32.60,  test loss 1.633843, test error 51.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.154115, train error 79.95,  test loss 2.117928, test error 77.72
# Epoch   100, train loss 1.177124, train error 39.65,  test loss 1.311544, test error 48.35
# Epoch   200, train loss 1.027206, train error 34.43,  test loss 1.393563, test error 47.92
# Epoch   300, train loss 0.969958, train error 32.68,  test loss 1.506712, test error 50.95
# Epoch   400, train loss 0.943921, train error 32.32,  test loss 1.599176, test error 51.38
# Epoch   500, train loss 0.892003, train error 29.72,  test loss 1.642868, test error 51.47
# Epoch   600, train loss 0.871444, train error 28.97,  test loss 1.724617, test error 51.62
# Epoch   700, train loss 0.865384, train error 29.03,  test loss 1.769086, test error 52.72
# Epoch   800, train loss 0.843094, train error 28.30,  test loss 1.807671, test error 52.83
# Epoch   900, train loss 0.854306, train error 29.32,  test loss 1.923963, test error 55.15
# Training model with  30 hidden variables
# Epoch     0, train loss 2.137436, train error 78.72,  test loss 2.096579, test error 78.28
# Epoch   100, train loss 1.117241, train error 37.72,  test loss 1.390844, test error 50.15
# Epoch   200, train loss 0.966321, train error 33.07,  test loss 1.582142, test error 52.00
# Epoch   300, train loss 0.887502, train error 30.05,  test loss 1.741792, test error 53.00
# Epoch   400, train loss 0.818422, train error 27.68,  test loss 1.883608, test error 52.55
# Epoch   500, train loss 0.781459, train error 26.97,  test loss 2.015491, test error 53.42
# Epoch   600, train loss 0.747617, train error 25.57,  test loss 2.135458, test error 53.90
# Epoch   700, train loss 0.741571, train error 25.50,  test loss 2.238577, test error 54.35
# Epoch   800, train loss 0.750788, train error 25.80,  test loss 2.380088, test error 55.40
# Epoch   900, train loss 0.705112, train error 23.47,  test loss 2.398782, test error 54.78
# Training model with  35 hidden variables
# Epoch     0, train loss 2.210183, train error 80.95,  test loss 2.218262, test error 82.12
# Epoch   100, train loss 1.030692, train error 34.40,  test loss 1.421282, test error 50.92
# Epoch   200, train loss 0.796887, train error 26.07,  test loss 1.742429, test error 54.00
# Epoch   300, train loss 0.666055, train error 21.95,  test loss 2.135454, test error 55.05
# Epoch   400, train loss 0.609326, train error 20.82,  test loss 2.487563, test error 56.78
# Epoch   500, train loss 0.548830, train error 18.30,  test loss 2.803855, test error 57.53
# Epoch   600, train loss 0.524548, train error 17.85,  test loss 3.149764, test error 57.45
# Epoch   700, train loss 0.494499, train error 17.03,  test loss 3.376078, test error 58.17
# Epoch   800, train loss 0.470732, train error 15.88,  test loss 3.645211, test error 57.90
# Epoch   900, train loss 0.473494, train error 16.28,  test loss 3.917582, test error 58.12
# Training model with  40 hidden variables
# Epoch     0, train loss 2.129843, train error 79.43,  test loss 2.102471, test error 78.03
# Epoch   100, train loss 0.959373, train error 30.95,  test loss 1.428179, test error 49.90
# Epoch   200, train loss 0.713354, train error 22.50,  test loss 1.826291, test error 51.28
# Epoch   300, train loss 0.565883, train error 18.32,  test loss 2.346501, test error 53.70
# Epoch   400, train loss 0.473284, train error 15.60,  test loss 2.920763, test error 54.70
# Epoch   500, train loss 0.394992, train error 13.47,  test loss 3.539789, test error 55.10
# Epoch   600, train loss 0.384577, train error 13.22,  test loss 4.273905, test error 56.78
# Epoch   700, train loss 0.315371, train error 11.15,  test loss 4.962947, test error 56.15
# Epoch   800, train loss 0.330314, train error 11.90,  test loss 5.618550, test error 56.83
# Epoch   900, train loss 0.281271, train error 9.70,  test loss 6.089060, test error 55.70
# Training model with  45 hidden variables
# Epoch     0, train loss 2.143453, train error 79.65,  test loss 2.115500, test error 79.28
# Epoch   100, train loss 0.843327, train error 26.32,  test loss 1.522258, test error 51.12
# Epoch   200, train loss 0.496083, train error 15.22,  test loss 2.279095, test error 54.40
# Epoch   300, train loss 0.329011, train error 10.55,  test loss 3.384111, test error 56.05
# Epoch   400, train loss 0.270276, train error 9.80,  test loss 4.599368, test error 56.80
# Epoch   500, train loss 0.210063, train error 7.25,  test loss 5.615338, test error 56.53
# Epoch   600, train loss 0.163180, train error 5.95,  test loss 6.767529, test error 57.58
# Epoch   700, train loss 0.051513, train error 1.00,  test loss 7.821176, test error 58.33
# Epoch   800, train loss 0.013921, train error 0.00,  test loss 9.038166, test error 58.15
# Epoch   900, train loss 0.009209, train error 0.00,  test loss 9.782192, test error 57.72
# Training model with  50 hidden variables
# Epoch     0, train loss 2.102261, train error 77.65,  test loss 2.050496, test error 76.78
# Epoch   100, train loss 0.740260, train error 23.03,  test loss 1.538588, test error 49.92
# Epoch   200, train loss 0.338524, train error 10.00,  test loss 2.592774, test error 53.70
# Epoch   300, train loss 0.134957, train error 2.53,  test loss 4.317964, test error 56.70
# Epoch   400, train loss 0.031680, train error 0.00,  test loss 5.878996, test error 57.05
# Epoch   500, train loss 0.014391, train error 0.00,  test loss 6.881917, test error 56.90
# Epoch   600, train loss 0.009002, train error 0.00,  test loss 7.545505, test error 56.92
# Epoch   700, train loss 0.006477, train error 0.00,  test loss 8.043585, test error 56.88
# Epoch   800, train loss 0.004992, train error 0.00,  test loss 8.441763, test error 56.88
# Epoch   900, train loss 0.004007, train error 0.00,  test loss 8.776834, test error 56.80
# Training model with  55 hidden variables
# Epoch     0, train loss 2.073601, train error 77.20,  test loss 2.027476, test error 75.80
# Epoch   100, train loss 0.620387, train error 18.90,  test loss 1.650387, test error 50.58
# Epoch   200, train loss 0.216729, train error 5.22,  test loss 3.011819, test error 52.97
# Epoch   300, train loss 0.037915, train error 0.05,  test loss 4.726460, test error 54.30
# Epoch   400, train loss 0.013522, train error 0.00,  test loss 5.704710, test error 54.08
# Epoch   500, train loss 0.007992, train error 0.00,  test loss 6.311708, test error 54.08
# Epoch   600, train loss 0.005544, train error 0.00,  test loss 6.743788, test error 54.03
# Epoch   700, train loss 0.004170, train error 0.00,  test loss 7.079266, test error 54.30
# Epoch   800, train loss 0.003289, train error 0.00,  test loss 7.350420, test error 54.17
# Epoch   900, train loss 0.002707, train error 0.00,  test loss 7.580969, test error 54.17
# Training model with  60 hidden variables
# Epoch     0, train loss 2.076982, train error 77.05,  test loss 2.052960, test error 76.35
# Epoch   100, train loss 0.529471, train error 15.78,  test loss 1.754830, test error 51.88
# Epoch   200, train loss 0.110031, train error 1.20,  test loss 3.486533, test error 55.72
# Epoch   300, train loss 0.019321, train error 0.00,  test loss 4.809411, test error 54.75
# Epoch   400, train loss 0.009365, train error 0.00,  test loss 5.538548, test error 55.10
# Epoch   500, train loss 0.005860, train error 0.00,  test loss 5.993617, test error 55.30
# Epoch   600, train loss 0.004178, train error 0.00,  test loss 6.329225, test error 55.45
# Epoch   700, train loss 0.003216, train error 0.00,  test loss 6.599497, test error 55.47
# Epoch   800, train loss 0.002580, train error 0.00,  test loss 6.823722, test error 55.45
# Epoch   900, train loss 0.002152, train error 0.00,  test loss 7.016190, test error 55.60
# Training model with  70 hidden variables
# Epoch     0, train loss 2.045137, train error 76.15,  test loss 1.980798, test error 74.80
# Epoch   100, train loss 0.349758, train error 8.57,  test loss 2.005802, test error 52.60
# Epoch   200, train loss 0.030927, train error 0.00,  test loss 3.726850, test error 53.75
# Epoch   300, train loss 0.010763, train error 0.00,  test loss 4.517262, test error 53.72
# Epoch   400, train loss 0.006032, train error 0.00,  test loss 4.962073, test error 53.65
# Epoch   500, train loss 0.004062, train error 0.00,  test loss 5.268582, test error 53.75
# Epoch   600, train loss 0.003009, train error 0.00,  test loss 5.500691, test error 53.53
# Epoch   700, train loss 0.002367, train error 0.00,  test loss 5.694705, test error 53.72
# Epoch   800, train loss 0.001936, train error 0.00,  test loss 5.854457, test error 53.92
# Epoch   900, train loss 0.001627, train error 0.00,  test loss 5.994565, test error 53.88
# Training model with  80 hidden variables
# Epoch     0, train loss 2.060808, train error 76.12,  test loss 2.041152, test error 78.60
# Epoch   100, train loss 0.253260, train error 4.75,  test loss 2.032541, test error 50.45
# Epoch   200, train loss 0.021159, train error 0.00,  test loss 3.428458, test error 51.35
# Epoch   300, train loss 0.008320, train error 0.00,  test loss 4.000124, test error 51.38
# Epoch   400, train loss 0.004877, train error 0.00,  test loss 4.332585, test error 51.72
# Epoch   500, train loss 0.003351, train error 0.00,  test loss 4.573980, test error 51.70
# Epoch   600, train loss 0.002513, train error 0.00,  test loss 4.757584, test error 51.80
# Epoch   700, train loss 0.001992, train error 0.00,  test loss 4.906743, test error 51.90
# Epoch   800, train loss 0.001637, train error 0.00,  test loss 5.032604, test error 52.05
# Epoch   900, train loss 0.001384, train error 0.00,  test loss 5.140182, test error 52.03
# Training model with  90 hidden variables
# Epoch     0, train loss 2.006182, train error 74.75,  test loss 1.961868, test error 75.82
# Epoch   100, train loss 0.161073, train error 2.00,  test loss 2.203968, test error 52.22
# Epoch   200, train loss 0.014941, train error 0.00,  test loss 3.277497, test error 51.85
# Epoch   300, train loss 0.006570, train error 0.00,  test loss 3.725211, test error 51.90
# Epoch   400, train loss 0.004004, train error 0.00,  test loss 4.000389, test error 51.62
# Epoch   500, train loss 0.002814, train error 0.00,  test loss 4.196728, test error 51.50
# Epoch   600, train loss 0.002141, train error 0.00,  test loss 4.352801, test error 51.50
# Epoch   700, train loss 0.001711, train error 0.00,  test loss 4.479043, test error 51.62
# Epoch   800, train loss 0.001415, train error 0.00,  test loss 4.586357, test error 51.50
# Epoch   900, train loss 0.001201, train error 0.00,  test loss 4.678771, test error 51.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.998274, train error 74.22,  test loss 1.953738, test error 75.10
# Epoch   100, train loss 0.084636, train error 0.07,  test loss 2.258491, test error 50.92
# Epoch   200, train loss 0.011806, train error 0.00,  test loss 3.088205, test error 51.20
# Epoch   300, train loss 0.005542, train error 0.00,  test loss 3.439904, test error 51.25
# Epoch   400, train loss 0.003469, train error 0.00,  test loss 3.663578, test error 51.30
# Epoch   500, train loss 0.002469, train error 0.00,  test loss 3.827812, test error 51.28
# Epoch   600, train loss 0.001892, train error 0.00,  test loss 3.953237, test error 51.03
# Epoch   700, train loss 0.001520, train error 0.00,  test loss 4.056561, test error 51.08
# Epoch   800, train loss 0.001263, train error 0.00,  test loss 4.145787, test error 51.00
# Epoch   900, train loss 0.001076, train error 0.00,  test loss 4.223357, test error 51.05
# Training model with 120 hidden variables
# Epoch     0, train loss 1.962484, train error 72.47,  test loss 1.885836, test error 72.70
# Epoch   100, train loss 0.047557, train error 0.00,  test loss 2.209407, test error 48.72
# Epoch   200, train loss 0.009186, train error 0.00,  test loss 2.805928, test error 49.05
# Epoch   300, train loss 0.004590, train error 0.00,  test loss 3.077395, test error 49.33
# Epoch   400, train loss 0.002938, train error 0.00,  test loss 3.254712, test error 49.53
# Epoch   500, train loss 0.002125, train error 0.00,  test loss 3.383962, test error 49.60
# Epoch   600, train loss 0.001644, train error 0.00,  test loss 3.485623, test error 49.62
# Epoch   700, train loss 0.001330, train error 0.00,  test loss 3.570841, test error 49.58
# Epoch   800, train loss 0.001112, train error 0.00,  test loss 3.643605, test error 49.60
# Epoch   900, train loss 0.000951, train error 0.00,  test loss 3.706577, test error 49.53
# Training model with 140 hidden variables
# Epoch     0, train loss 1.961910, train error 73.18,  test loss 1.892239, test error 74.20
# Epoch   100, train loss 0.037663, train error 0.00,  test loss 2.186219, test error 49.33
# Epoch   200, train loss 0.008157, train error 0.00,  test loss 2.694787, test error 49.53
# Epoch   300, train loss 0.004163, train error 0.00,  test loss 2.931568, test error 49.50
# Epoch   400, train loss 0.002694, train error 0.00,  test loss 3.088851, test error 49.45
# Epoch   500, train loss 0.001956, train error 0.00,  test loss 3.204576, test error 49.53
# Epoch   600, train loss 0.001519, train error 0.00,  test loss 3.296720, test error 49.50
# Epoch   700, train loss 0.001233, train error 0.00,  test loss 3.373603, test error 49.47
# Epoch   800, train loss 0.001032, train error 0.00,  test loss 3.438245, test error 49.50
# Epoch   900, train loss 0.000884, train error 0.00,  test loss 3.494663, test error 49.53
# Training model with 160 hidden variables
# Epoch     0, train loss 1.920960, train error 69.60,  test loss 1.845958, test error 70.53
# Epoch   100, train loss 0.029247, train error 0.00,  test loss 2.132059, test error 48.83
# Epoch   200, train loss 0.007291, train error 0.00,  test loss 2.552316, test error 48.92
# Epoch   300, train loss 0.003803, train error 0.00,  test loss 2.758554, test error 48.95
# Epoch   400, train loss 0.002500, train error 0.00,  test loss 2.896463, test error 49.05
# Epoch   500, train loss 0.001832, train error 0.00,  test loss 2.997803, test error 49.08
# Epoch   600, train loss 0.001430, train error 0.00,  test loss 3.079890, test error 49.08
# Epoch   700, train loss 0.001165, train error 0.00,  test loss 3.148293, test error 49.08
# Epoch   800, train loss 0.000977, train error 0.00,  test loss 3.206736, test error 49.08
# Epoch   900, train loss 0.000839, train error 0.00,  test loss 3.257640, test error 49.00
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917436, train error 70.55,  test loss 1.847679, test error 71.18
# Epoch   100, train loss 0.024059, train error 0.00,  test loss 2.073728, test error 48.83
# Epoch   200, train loss 0.006586, train error 0.00,  test loss 2.434217, test error 48.28
# Epoch   300, train loss 0.003538, train error 0.00,  test loss 2.615695, test error 48.30
# Epoch   400, train loss 0.002345, train error 0.00,  test loss 2.737324, test error 48.17
# Epoch   500, train loss 0.001726, train error 0.00,  test loss 2.827565, test error 48.20
# Epoch   600, train loss 0.001352, train error 0.00,  test loss 2.900298, test error 48.25
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.961374, test error 48.20
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 3.013553, test error 48.30
# Epoch   900, train loss 0.000798, train error 0.00,  test loss 3.059723, test error 48.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.922645, train error 70.88,  test loss 1.841389, test error 72.30
# Epoch   100, train loss 0.021765, train error 0.00,  test loss 2.036784, test error 48.60
# Epoch   200, train loss 0.006151, train error 0.00,  test loss 2.356366, test error 48.45
# Epoch   300, train loss 0.003349, train error 0.00,  test loss 2.518849, test error 48.22
# Epoch   400, train loss 0.002234, train error 0.00,  test loss 2.630073, test error 48.12
# Epoch   500, train loss 0.001650, train error 0.00,  test loss 2.713642, test error 48.20
# Epoch   600, train loss 0.001296, train error 0.00,  test loss 2.780318, test error 48.45
# Epoch   700, train loss 0.001060, train error 0.00,  test loss 2.836891, test error 48.42
# Epoch   800, train loss 0.000893, train error 0.00,  test loss 2.884871, test error 48.40
# Epoch   900, train loss 0.000768, train error 0.00,  test loss 2.926325, test error 48.30
# Training model with 250 hidden variables
# Epoch     0, train loss 1.929055, train error 71.45,  test loss 1.851307, test error 72.90
# Epoch   100, train loss 0.017257, train error 0.00,  test loss 1.927581, test error 47.05
# Epoch   200, train loss 0.005397, train error 0.00,  test loss 2.189301, test error 47.15
# Epoch   300, train loss 0.003006, train error 0.00,  test loss 2.325536, test error 47.33
# Epoch   400, train loss 0.002027, train error 0.00,  test loss 2.419756, test error 47.45
# Epoch   500, train loss 0.001508, train error 0.00,  test loss 2.490628, test error 47.50
# Epoch   600, train loss 0.001190, train error 0.00,  test loss 2.548241, test error 47.70
# Epoch   700, train loss 0.000976, train error 0.00,  test loss 2.596050, test error 47.65
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.637446, test error 47.67
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.673255, test error 47.72
# Training model with 300 hidden variables
# Epoch     0, train loss 1.911665, train error 69.90,  test loss 1.843648, test error 73.25
# Epoch   100, train loss 0.014801, train error 0.00,  test loss 1.880050, test error 46.72
# Epoch   200, train loss 0.004927, train error 0.00,  test loss 2.105301, test error 46.67
# Epoch   300, train loss 0.002778, train error 0.00,  test loss 2.228339, test error 46.83
# Epoch   400, train loss 0.001891, train error 0.00,  test loss 2.312229, test error 46.90
# Epoch   500, train loss 0.001414, train error 0.00,  test loss 2.376785, test error 46.90
# Epoch   600, train loss 0.001120, train error 0.00,  test loss 2.428654, test error 46.88
# Epoch   700, train loss 0.000922, train error 0.00,  test loss 2.471911, test error 46.80
# Epoch   800, train loss 0.000780, train error 0.00,  test loss 2.510068, test error 46.83
# Epoch   900, train loss 0.000674, train error 0.00,  test loss 2.542766, test error 46.83
# Training model with 400 hidden variables
# Epoch     0, train loss 1.871086, train error 67.82,  test loss 1.803875, test error 69.95
# Epoch   100, train loss 0.011557, train error 0.00,  test loss 1.825791, test error 46.47
# Epoch   200, train loss 0.004132, train error 0.00,  test loss 2.012091, test error 46.67
# Epoch   300, train loss 0.002396, train error 0.00,  test loss 2.116213, test error 46.65
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.187857, test error 46.55
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.243684, test error 46.62
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.288613, test error 46.65
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.326295, test error 46.58
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.359624, test error 46.62
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.388366, test error 46.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
