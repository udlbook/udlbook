# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to C:\Users\STEVE\AppData\Local\Temp\pip-req-build-0_52ujjj
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mnist1d==0.0.2.post16) (2.32.5)
# Requirement already satisfied: numpy in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mnist1d==0.0.2.post16) (2.3.4)
# Requirement already satisfied: matplotlib in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mnist1d==0.0.2.post16) (3.10.7)
# Requirement already satisfied: scipy in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\STEVE\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\STEVE\AppData\Local\Temp\pip-req-build-0_52ujjj'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_k), torch.nn.ReLU(), torch.nn.Linear(D_k, D_k), torch.nn.ReLU(), torch.nn.Linear(D_k, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.normal_(layer_in.weight, mean=0.0, std=np.sqrt(2.0/layer_in.in_features))
    torch.nn.init.constant_(layer_in.bias, 0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.609881, train error 62.35,  test loss 1.674281, test error 67.50
# Epoch     1, train loss 1.323231, train error 48.55,  test loss 1.457994, test error 58.40
# Epoch     2, train loss 1.121310, train error 40.28,  test loss 1.322832, test error 51.80
# Epoch     3, train loss 0.992291, train error 35.10,  test loss 1.256139, test error 49.30
# Epoch     4, train loss 0.873241, train error 30.32,  test loss 1.179187, test error 45.20
# Epoch     5, train loss 0.805972, train error 28.30,  test loss 1.216019, test error 46.40
# Epoch     6, train loss 0.723507, train error 25.38,  test loss 1.153481, test error 43.90
# Epoch     7, train loss 0.655085, train error 22.93,  test loss 1.137789, test error 42.80
# Epoch     8, train loss 0.576124, train error 20.10,  test loss 1.135395, test error 41.30
# Epoch     9, train loss 0.499287, train error 17.32,  test loss 1.123030, test error 40.30
# Epoch    10, train loss 0.400976, train error 11.47,  test loss 1.070200, test error 39.70
# Epoch    11, train loss 0.365941, train error 10.38,  test loss 1.079781, test error 38.10
# Epoch    12, train loss 0.338677, train error 8.50,  test loss 1.091138, test error 39.00
# Epoch    13, train loss 0.304627, train error 7.85,  test loss 1.105275, test error 38.50
# Epoch    14, train loss 0.280410, train error 6.90,  test loss 1.116468, test error 38.90
# Epoch    15, train loss 0.256594, train error 6.30,  test loss 1.114720, test error 37.60
# Epoch    16, train loss 0.242305, train error 5.95,  test loss 1.194358, test error 41.00
# Epoch    17, train loss 0.226897, train error 5.45,  test loss 1.194498, test error 38.70
# Epoch    18, train loss 0.189319, train error 3.50,  test loss 1.194417, test error 38.90
# Epoch    19, train loss 0.172772, train error 2.65,  test loss 1.199722, test error 38.90
# Epoch    20, train loss 0.147560, train error 1.45,  test loss 1.196961, test error 38.30
# Epoch    21, train loss 0.138499, train error 1.30,  test loss 1.217377, test error 38.40
# Epoch    22, train loss 0.132519, train error 1.30,  test loss 1.227106, test error 38.10
# Epoch    23, train loss 0.124813, train error 0.90,  test loss 1.229576, test error 38.00
# Epoch    24, train loss 0.120869, train error 0.93,  test loss 1.240213, test error 38.30
# Epoch    25, train loss 0.110512, train error 0.45,  test loss 1.260185, test error 38.70
# Epoch    26, train loss 0.105868, train error 0.47,  test loss 1.282460, test error 37.90
# Epoch    27, train loss 0.103704, train error 0.62,  test loss 1.284571, test error 38.40
# Epoch    28, train loss 0.095570, train error 0.35,  test loss 1.288441, test error 38.40
# Epoch    29, train loss 0.089916, train error 0.30,  test loss 1.301155, test error 38.30
# Epoch    30, train loss 0.086754, train error 0.18,  test loss 1.309830, test error 38.10
# Epoch    31, train loss 0.084098, train error 0.18,  test loss 1.309301, test error 38.40
# Epoch    32, train loss 0.082689, train error 0.12,  test loss 1.318859, test error 38.40
# Epoch    33, train loss 0.080317, train error 0.18,  test loss 1.323706, test error 38.30
# Epoch    34, train loss 0.078218, train error 0.12,  test loss 1.328044, test error 38.30
# Epoch    35, train loss 0.076507, train error 0.12,  test loss 1.330199, test error 37.80
# Epoch    36, train loss 0.075208, train error 0.12,  test loss 1.342623, test error 38.60
# Epoch    37, train loss 0.072943, train error 0.10,  test loss 1.339679, test error 38.20
# Epoch    38, train loss 0.071987, train error 0.12,  test loss 1.349508, test error 38.50
# Epoch    39, train loss 0.069777, train error 0.12,  test loss 1.353717, test error 38.70
# Epoch    40, train loss 0.068845, train error 0.10,  test loss 1.359578, test error 38.20
# Epoch    41, train loss 0.067808, train error 0.10,  test loss 1.358020, test error 38.10
# Epoch    42, train loss 0.067200, train error 0.07,  test loss 1.364246, test error 38.10
# Epoch    43, train loss 0.066398, train error 0.07,  test loss 1.365217, test error 38.20
# Epoch    44, train loss 0.065670, train error 0.05,  test loss 1.366582, test error 38.20
# Epoch    45, train loss 0.064997, train error 0.05,  test loss 1.371443, test error 38.50
# Epoch    46, train loss 0.064238, train error 0.05,  test loss 1.373442, test error 38.30
# Epoch    47, train loss 0.063600, train error 0.05,  test loss 1.376026, test error 38.20
# Epoch    48, train loss 0.063138, train error 0.05,  test loss 1.379860, test error 38.30
# Epoch    49, train loss 0.062328, train error 0.05,  test loss 1.381366, test error 38.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
